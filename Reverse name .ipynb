# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

print(last_name + " " + first_name)
# Out:
# Enter your first name:  Syed
# Enter your last name:  Ezan
# Ezan Syed
