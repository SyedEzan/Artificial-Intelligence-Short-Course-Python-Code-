# %% [markdown]
# ## Calculator

# %%
## Create a calculator in Python that performs the following operations:
## addition, subtraction, multiplication, division, and exponentiation (power)

print("Simple Calculator")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

choice = input("Enter choice (1-5): ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == '1':
    print("Result:", num1 + num2)

elif choice == '2':
    print("Result:", num1 - num2)

elif choice == '3':
    print("Result:", num1 * num2)

elif choice == '4':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero!")

elif choice == '5':
    print("Result:", num1 ** num2)

else:
    print("Invalid choice")
# Out:
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Enter choice (1-5):  4
# Enter first number:  55
# Enter second number:  2
# Result: 27.5

# %%
## Write a Python program using a for loop to check whether a list contains any numeric value.

my_list = ["Ezan", 25, "Python", 3.14, "AI"]

for item in my_list:
    if isinstance(item, (int, float)):
        print("Numeric value found:", item)
        break
else:
    print("No numeric value found")
# Out:
# Numeric value found: 25

# %%
## Write a Python script to add a new key and value to an existing dictionary.

student = {
    "name": "Ali",
    "age": 20
}

student["grade"] = "A"

print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'grade': 'A'}

# %%
## Write a Python program to calculate the sum of all numeric values present in a dictionary.

data = {
    "a": 10,
    "b": 20,
    "c": "Hello",
    "d": 30
}

total = 0

for value in data.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum of numeric values:", total)
# Out:
# Sum of numeric values: 60

# %%
## Write a Python program to identify and display duplicate values from a given list.

my_list = [1, 2, 3, 4, 2, 5, 6, 1, 7]

duplicates = []

for item in my_list:
    if my_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]

# %%
## Write a Python script to check whether a given key already exists in a dictionary.
my_dict = {
    "name": "Ezan",
    "course": "Python",
    "city": "Karachi"
}

key = input("Enter key to check: ")

if key in my_dict:
    print("Key exists in dictionary")
else:
    print("Key does not exist")
# Out:
# Enter key to check:  name
# Key exists in dictionary
